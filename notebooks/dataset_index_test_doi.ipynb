# %% [markdown]
# # Test dataset index calculation for URL

# %% [markdown]
# ## Import

# %%
from sindex.metrics.jobs import dataset_index_series_from_url

# %% [markdown]
# ## Tests

# %% [markdown]
# ### Validate dataset URL available in MDC

# %% [markdown]
# ### DOI

# %%
doi = "10.13026/kpb9-mt58" 
dataset_report = dataset_index_series_from_url(doi)
display(dataset_report)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 doi = "10.13026/kpb9-mt58"
# ----> 2 dataset_report = dataset_index_series_from_url(doi)
#       3 display(dataset_report)
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\metrics\jobs.py:196, in dataset_index_series_from_url(url, identifier, pubdate, topic_id)
#     193 url = url.strip()
#     195 if not url.startswith(("http://", "https://")):
# --> 196     raise ValueError(
#     197         f"Invalid URL format: {url} (must start with http:// or https://)"
#     198     )
#     199 if not is_url(url):
#     200     raise ValueError(f"Invalid URL format: {url}")
#
# ValueError: Invalid URL format: 10.13026/kpb9-mt58 (must start with http:// or https://)

# %%
display(dataset_report["dataset_index_series"])
# Out:
# [{'date': '2024-10-10T21:27:19Z', 'dataset_index': 0.398755832037325},
#  {'date': '2024-11-10T21:00:19Z', 'dataset_index': 0.4898015316749101},
#  {'date': '2024-11-26T00:00:00Z', 'dataset_index': 0.5525352751904126},
#  {'date': '2024-12-03T05:44:50Z', 'dataset_index': 0.6444649136594306},
#  {'date': '2024-12-13T00:00:00Z', 'dataset_index': 0.7078018662471974},
#  {'date': '2025-01-01T00:00:00Z', 'dataset_index': 0.7723452369794933},
#  {'date': '2025-01-06T19:34:58Z', 'dataset_index': 0.8669266919428099},
#  {'date': '2025-02-01T00:00:00Z', 'dataset_index': 0.9326764808196346},
#  {'date': '2025-02-10T00:00:00Z', 'dataset_index': 0.9990294787687238},
#  {'date': '2025-02-12T00:00:00Z', 'dataset_index': 1.0653824767178128},
#  {'date': '2025-02-13T00:00:00Z', 'dataset_index': 1.131735474666902},
#  {'date': '2025-03-01T00:00:00Z', 'dataset_index': 1.1986916816882556},
#  {'date': '2025-03-08T00:00:00Z', 'dataset_index': 1.2656478887096092},
#  {'date': '2025-03-15T00:00:00Z', 'dataset_index': 1.3332073048032271},
#  {'date': '2025-03-21T00:00:00Z', 'dataset_index': 1.4007667208968453},
#  {'date': '2025-03-27T00:00:00Z', 'dataset_index': 1.4683261369904634},
#  {'date': '2025-04-17T00:00:00Z', 'dataset_index': 1.5370919712286104},
#  {'date': '2025-04-18T14:38:42Z', 'dataset_index': 1.6378609980119567},
#  {'date': '2025-04-25T00:00:00Z', 'dataset_index': 1.7066268322501037},
#  {'date': '2025-04-29T17:10:26Z', 'dataset_index': 1.8073958590334502},
#  {'date': '2025-05-09T09:32:17Z', 'dataset_index': 1.90904882464823},
#  {'date': '2025-05-13T00:00:00Z', 'dataset_index': 1.9784178679586413},
#  {'date': '2025-05-18T20:02:37Z', 'dataset_index': 2.0809547724048536},
#  {'date': '2025-05-21T00:00:00Z', 'dataset_index': 2.150927024787529},
#  {'date': '2025-06-01T00:00:00Z', 'dataset_index': 2.220899277170205},
#  {'date': '2025-06-10T00:00:00Z', 'dataset_index': 2.2914747386251455},
#  {'date': '2025-06-18T00:00:00Z', 'dataset_index': 2.362050200080086},
#  {'date': '2025-06-19T00:00:00Z', 'dataset_index': 2.432625661535026},
#  {'date': '2025-06-27T00:00:00Z', 'dataset_index': 2.503804332062231},
#  {'date': '2025-07-09T00:00:00Z', 'dataset_index': 2.5749830025894354},
#  {'date': '2025-07-21T00:00:00Z', 'dataset_index': 2.6467648821889047},
#  {'date': '2025-07-23T00:00:00Z', 'dataset_index': 2.7903286413878434},
#  {'date': '2025-07-24T00:00:00Z', 'dataset_index': 2.862110520987313},
#  {'date': '2025-07-30T00:00:00Z', 'dataset_index': 2.9338924005867817},
#  {'date': '2025-08-02T00:00:00Z', 'dataset_index': 3.0062774892585153},
#  {'date': '2025-08-13T00:00:00Z', 'dataset_index': 3.078662577930249},
#  {'date': '2025-08-19T00:00:00Z', 'dataset_index': 3.1510476666019827},
#  {'date': '2025-08-21T00:00:00Z', 'dataset_index': 3.2234327552737168},
#  {'date': '2025-08-27T00:00:00Z', 'dataset_index': 3.296421053017715},
#  {'date': '2025-08-28T00:00:00Z', 'dataset_index': 3.3694093507617127},
#  {'date': '2025-09-06T00:00:00Z', 'dataset_index': 3.442397648505711},
#  {'date': '2025-09-08T18:44:43Z', 'dataset_index': 3.549354247109088},
#  {'date': '2025-09-11T23:13:37Z', 'dataset_index': 3.6571947845438975},
#  {'date': '2025-09-19T00:00:00Z', 'dataset_index': 3.7307862913601597},
#  {'date': '2025-10-09T00:00:00Z', 'dataset_index': 3.8049810072486867},
#  {'date': '2025-10-15T00:00:00Z', 'dataset_index': 3.8791757231372137},
#  {'date': '2025-10-17T00:00:00Z', 'dataset_index': 3.9533704390257403},
#  {'date': '2025-10-20T00:00:00Z', 'dataset_index': 4.027565154914267},
#  {'date': '2025-10-21T00:00:00Z', 'dataset_index': 4.101759870802794},
#  {'date': '2025-11-01T00:00:00Z', 'dataset_index': 4.251355720724377},
#  {'date': '2025-11-03T00:00:00Z', 'dataset_index': 4.40095157064596},
#  {'date': '2025-11-04T08:32:29Z', 'dataset_index': 4.510559985743636},
#  {'date': '2025-11-13T00:00:00Z', 'dataset_index': 4.585357910704427},
#  {'date': '2025-11-14T00:00:00Z', 'dataset_index': 4.660155835665218},
#  {'date': '2025-11-26T00:00:00Z', 'dataset_index': 4.8109581037313305},
#  {'date': '2025-12-01T00:00:00Z', 'dataset_index': 4.886359237764386},
#  {'date': '2025-12-03T00:00:00Z', 'dataset_index': 4.961760371797442},
#  {'date': '2025-12-05T00:00:00Z', 'dataset_index': 5.037161505830498},
#  {'date': '2025-12-08T00:00:00Z', 'dataset_index': 5.112562639863554},
#  {'date': '2025-12-11T18:57:26Z', 'dataset_index': 5.223938932624095},
#  {'date': '2025-12-23T00:00:00Z', 'dataset_index': 5.299943275729414},
#  {'date': '2026-01-01T00:00:00Z', 'dataset_index': 5.3759476188347355},
#  {'date': '2026-01-03T00:00:00Z', 'dataset_index': 5.451951961940055},
#  {'date': '2026-01-05T10:26:11Z', 'dataset_index': 5.564212193532029},
#  {'date': '2026-01-05T10:59:54Z', 'dataset_index': 5.676472425124003},
#  {'date': '2026-01-06T00:00:00Z', 'dataset_index': 5.906295081656757},
#  {'date': '2026-01-07T00:00:00Z', 'dataset_index': 5.982902633834342},
#  {'date': '2026-01-12T00:00:00Z', 'dataset_index': 6.059510186011926}]

# %% [markdown]
# ### Valid DOI URL

# %%
doi = "https://doi.org/10.1038/s42255-024-01165-x" 
dataset_report = dataset_index_series_from_url(doi)

# %%
display(dataset_report)
# Out:
# {'input_url': 'https://doi.org/10.1038/s42255-024-01165-x',
#  'norm_url': '10.1038/s42255-024-01165-x',
#  'input_identifier': None,
#  'norm_identifier': '',
#  'metadata': None,
#  'topic': None,
#  'fair': {'fair_score': 73.08,
#   'evaluation_date': '2026-01-15T16:20:55+00:00',
#   'fuji_metric_version': '0.8',
#   'fuji_software_version': '3.5.1'},
#  'citations': None,
#  'mentions': None,
#  'normalization_factors': {'FT': 0.61,
#   'CTw': 3.925,
#   'MTw': 2.814,
#   'topic_id_used': 'ALL',
#   'year_used': -1,
#   'topic_id_requested': None,
#   'year_requested': None,
#   'used_year_clamp': False},
#  'dataset_index_series': None}
