# %% [markdown]
# # Test MDC citations harvesting code

# %% [markdown]
# ## Import

# %%
from sindex.sources.mdc.jobs import build_mdc_index, find_citations_mdc_duckdb
import os
import duckdb
import pandas as df

# %% [markdown]
# ## Build MDC DuckDB table

# %%
mdc_path = r"C:\Users\BPatel\Documents\GitHub\sindex-pipeline\input\mdc"
db_path = os.path.join(mdc_path, "mdc_index.duckdb")

# %%
build_mdc_index(
    mdc_folder = mdc_path,
    db_path = db_path)
# Out:
# 'C:\\Users\\BPatel\\Documents\\GitHub\\sindex-pipeline\\input\\mdc\\mdc_index.duckdb'

# %%
con = duckdb.connect(db_path, read_only=True)

con.execute("SHOW TABLES").fetchall()
con.execute("DESCRIBE mdc_index").df()
con.execute("SELECT * FROM mdc_index LIMIT 20").df()
# Out:
#                        dataset_norm  \
# 0                10.13026/kpb9-mt58
# 1                          op288111
# 2                10.13026/kpb9-mt58
# 3                10.13026/kpb9-mt58
# 4  https://emdb-empiar.org/emd-1003
# 5                         srr039616
# 6                          emd-2451
# 7                           sq22536
# 8                          emd-2451
#
#                                 citation_link              citation_date
# 0  https://doi.org/10.3389/fcimb.2025.1545979  2025-04-17T00:00:00+00:00
# 1   https://doi.org/10.3390/pathogens12020175  2023-01-23T00:00:00+00:00
# 2       https://doi.org/10.1093/jamia/ocae303  2024-12-13T00:00:00+00:00
# 3           https://doi.org/10.1002/alz.14564  2025-03-29T00:00:00+00:00
# 4     https://doi.org/10.1002/1873-3468.13086  2018-05-25T00:00:00+00:00
# 5        https://doi.org/10.1155/2016/2596782  2016-01-01T00:00:00+00:00
# 6   https://doi.org/10.1007/s10969-014-9179-9  2014-04-20T00:00:00+00:00
# 7        https://doi.org/10.3390/ijms19061818  2018-06-20T00:00:00+00:00
# 8           https://doi.org/10.1038/nsmb.2736  2013-12-15T00:00:00+00:00

# %% [markdown]
# ## Find citations

# %% [markdown]
# ### DOI

# %%
doi = "10.13026/kpb9-mt58"
dataset_pub_date = "2024-10-10T21:27:19+00:00"

# %%
find_citations_mdc_duckdb(doi, dataset_pub_date = dataset_pub_date, db_path = db_path)
# Out:
# [{'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['mdc'],
#   'citation_link': 'https://doi.org/10.3389/fcimb.2025.1545979',
#   'citation_weight': 1.14,
#   'citation_date': '2025-04-17T00:00:00+00:00'},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['mdc'],
#   'citation_link': 'https://doi.org/10.1093/jamia/ocae303',
#   'citation_weight': 1.05,
#   'citation_date': '2024-12-13T00:00:00+00:00'},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['mdc'],
#   'citation_link': 'https://doi.org/10.1002/alz.14564',
#   'citation_weight': 1.13,
#   'citation_date': '2025-03-29T00:00:00+00:00'}]
