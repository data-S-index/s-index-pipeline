# %% [markdown]
# # Test DataCite dataset harvesting code

# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sindex.sources.datacite.discovery import get_datacite_doi_record 
from sindex.sources.datacite.normalize import slim_datacite_record
from sindex.sources.datacite.jobs import (
    harvest_datacite_doi_list_to_ndjson,
    harvest_datacite_datasets_for_date_range_to_ndjson,
    batch_slim_datacite_record_to_ndjson
    )
from pathlib import Path

# %% [markdown]
# ## Get record for single DOI and create slim metadata

# %% [markdown]
# ### Valid DOI found in DataCite

# %%
doi = "10.13026/kpb9-mt58"

rec = get_datacite_doi_record(doi)

if rec is None:
    print("No record found.")
else:
    print("Success")
    display(rec)
# Out:
# Success
# {'id': '10.13026/kpb9-mt58',
#  'type': 'dois',
#  'attributes': {'doi': '10.13026/kpb9-mt58',
#   'prefix': '10.13026',
#   'suffix': 'kpb9-mt58',
#   'identifiers': [],
#   'alternateIdentifiers': [],
#   'creators': [{'name': 'Johnson, Alistair',
#     'givenName': 'Alistair',
#     'familyName': 'Johnson',
#     'affiliation': ['Massachusetts Institute of Technology'],
#     'nameIdentifiers': []},
#    {'name': 'Bulgarelli, Lucas',
#     'givenName': 'Lucas',
#     'familyName': 'Bulgarelli',
#     'affiliation': ['Massachusetts Institute of Technology'],
#     'nameIdentifiers': []},
#    {'name': 'Pollard, Tom',
#     'givenName': 'Tom',
#     'familyName': 'Pollard',
#     'affiliation': ['Massachusetts Institute of Technology, USA'],
#     'nameIdentifiers': [{'schemeUri': 'https://orcid.org/',
#       'nameIdentifier': 'https://orcid.org/0000-0002-5676-7898',
#       'nameIdentifierScheme': 'ORCID'}]},
#    {'name': 'Gow, Brian',
#     'givenName': 'Brian',
#     'familyName': 'Gow',
#     'affiliation': ['Massachusetts Institute of Technology'],
#     'nameIdentifiers': [{'schemeUri': 'https://orcid.org/',
#       'nameIdentifier': 'https://orcid.org/0000-0002-7682-1943',
#       'nameIdentifierScheme': 'ORCID'}]},
#    {'name': 'Moody, Benjamin',
#     'givenName': 'Benjamin',
#     'familyName': 'Moody',
#     'affiliation': ['Massachusetts Institute of Technology'],
#     'nameIdentifiers': []},
#    {'name': 'Horng, Steven',
#     'givenName': 'Steven',
#     'familyName': 'Horng',
#     'affiliation': ['Beth Israel Deaconess Medical Center',
#      'Harvard Medical School'],
#     'nameIdentifiers': []},
#    {'name': 'Celi, Leo Anthony',
#     'givenName': 'Leo Anthony',
#     'familyName': 'Celi',
#     'affiliation': ['Massachusetts Institute of Technology, Cambridge, USA',
#      'Beth Israel Deaconess Medical Center, Boston, USA'],
#     'nameIdentifiers': []},
#    {'name': 'Mark, Roger',
#     'givenName': 'Roger',
#     'familyName': 'Mark',
#     'affiliation': ['Massachusetts Institute of Technology'],
#     'nameIdentifiers': [{'schemeUri': 'https://orcid.org/',
#       'nameIdentifier': 'https://orcid.org/0000-0002-6318-2978',
#       'nameIdentifierScheme': 'ORCID'}]}],
#   'titles': [{'title': 'MIMIC-IV'}],
#   'publisher': 'PhysioNet',
#   'container': {},
#   'publicationYear': 2024,
#   'subjects': [],
#   'contributors': [],
#   'dates': [],
#   'language': None,
#   'types': {'ris': 'DATA',
#    'bibtex': 'misc',
#    'citeproc': 'dataset',
#    'schemaOrg': 'Dataset',
#    'resourceTypeGeneral': 'Dataset'},
#   'relatedIdentifiers': [{'relationType': 'IsVersionOf',
#     'relatedIdentifier': '10.13026/07hj-2a80',
#     'relatedIdentifierType': 'DOI'}],
#   'relatedItems': [],
#   'sizes': [],
#   'formats': [],
#   'version': '3.1',
#   'rightsList': [],
#   'descriptions': [{'description': 'Retrospectively collected medical data has the opportunity to improve patient\ncare through knowledge discovery and algorithm development. Broad reuse of\nmedical data is desirable for the greatest public good, but data sharing must\nbe done in a manner which protects patient privacy. Here we present Medical\nInformation Mart for Intensive Care (MIMIC)-IV, a large deidentified dataset\nof patients admitted to the emergency department or an intensive care unit at\nthe Beth Israel Deaconess Medical Center in Boston, MA. MIMIC-IV contains data\nfor over 65,000 patients admitted to an ICU and over 200,000 patients admitted\nto the emergency department. MIMIC-IV incorporates contemporary data and\nadopts a modular approach to data organization, highlighting data provenance\nand facilitating both individual and combined use of disparate data sources.\nMIMIC-IV is intended to carry on the success of MIMIC-III and support a broad\nset of applications within healthcare.\n\n',
#     'descriptionType': 'Abstract'}],
#   'geoLocations': [],
#   'fundingReferences': [],
#   'xml': '...',
#   'url': 'https://physionet.org/content/mimiciv/3.1/',
#   'contentUrl': None,
#   'metadataVersion': 0,
#   'schemaVersion': 'http://datacite.org/schema/kernel-4',
#   'source': 'api',
#   'isActive': True,
#   'state': 'findable',
#   'reason': None,
#   'viewCount': 0,
#   'viewsOverTime': [],
#   'downloadCount': 0,
#   'downloadsOverTime': [],
#   'referenceCount': 2,
#   'citationCount': 49,
#   'citationsOverTime': [{'year': '2024', 'total': 1},
#    {'year': '2025', 'total': 42},
#    {'year': '2026', 'total': 6}],
#   'partCount': 0,
#   'partOfCount': 0,
#   'versionCount': 0,
#   'versionOfCount': 1,
#   'created': '2024-10-10T21:27:19.000Z',
#   'registered': '2024-10-11T21:54:29.000Z',
#   'published': '2024',
#   'updated': '2025-04-06T08:55:21.000Z'},
#  'relationships': {'client': {'data': {'id': 'mit.physio', 'type': 'clients'}},
#   'provider': {'data': {'id': 'mit', 'type': 'providers'}},
#   'media': {'data': {'id': '10.13026/kpb9-mt58', 'type': 'media'}},
#   'references': {'data': [{'id': '10.5281/zenodo.18248285', 'type': 'dois'},
#     {'id': '10.5281/zenodo.18248286', 'type': 'dois'}]},
#   'citations': {'data': [{'id': '10.1093/jamia/ocae303', 'type': 'dois'},
#     {'id': '10.1101/2025.02.11.25321833', 'type': 'dois'},
#     {'id': '10.32628/cseit251112256', 'type': 'dois'},
#     {'id': '10.2196/preprints.74142', 'type': 'dois'},
#     {'id': '10.1101/2025.03.26.25324714', 'type': 'dois'},
#     {'id': '10.1002/alz.14564', 'type': 'dois'},
#     {'id': '10.1016/j.numecd.2025.103973', 'type': 'dois'},
#     {'id': '10.1186/s40560-025-00797-9', 'type': 'dois'},
#     {'id': '10.1089/pmr.2025.0015', 'type': 'dois'},
#     {'id': '10.7759/cureus.86370', 'type': 'dois'},
#     {'id': '10.1101/2025.06.26.25330281', 'type': 'dois'},
#     {'id': '10.1186/s12871-025-03243-3', 'type': 'dois'},
#     {'id': '10.1007/s40520-025-03115-3', 'type': 'dois'},
#     {'id': '10.1038/s41598-025-14028-6', 'type': 'dois'},
#     {'id': '10.21203/rs.3.rs-6680914/v1', 'type': 'dois'},
#     {'id': '10.1038/s41598-025-12496-4', 'type': 'dois'},
#     {'id': '10.1101/2025.07.20.25322556', 'type': 'dois'},
#     {'id': '10.1186/s40779-025-00641-z', 'type': 'dois'},
#     {'id': '10.1101/2025.08.15.25333725', 'type': 'dois'},
#     {'id': '10.3389/fphar.2025.1622440', 'type': 'dois'},
#     {'id': '10.2196/74142', 'type': 'dois'},
#     {'id': '10.1145/3705328.3748022', 'type': 'dois'},
#     {'id': '10.1530/ec-25-0377', 'type': 'dois'},
#     {'id': '10.1093/gigascience/giaf107', 'type': 'dois'},
#     {'id': '10.1038/s41597-025-05915-8', 'type': 'dois'},
#     {'id': '10.1016/j.diabres.2025.112105', 'type': 'dois'},
#     {'id': '10.1186/s13054-025-05642-x', 'type': 'dois'},
#     {'id': '10.1016/j.jad.2025.120465', 'type': 'dois'},
#     {'id': '10.1101/2025.08.25.25334266', 'type': 'dois'},
#     {'id': '10.21203/rs.3.rs-7886784/v1', 'type': 'dois'},
#     {'id': '10.3389/fcvm.2025.1599318', 'type': 'dois'},
#     {'id': '10.1016/j.aucc.2025.101489', 'type': 'dois'},
#     {'id': '10.1186/s12872-025-05231-4', 'type': 'dois'},
#     {'id': '10.1101/2025.11.11.25340038', 'type': 'dois'},
#     {'id': '10.1016/j.bja.2025.10.043', 'type': 'dois'},
#     {'id': '10.1038/s41598-025-26223-6', 'type': 'dois'},
#     {'id': '10.1177/08850666251358154', 'type': 'dois'},
#     {'id': '10.1080/15563650.2025.2555970', 'type': 'dois'},
#     {'id': '10.1016/j.mcna.2025.07.011', 'type': 'dois'},
#     {'id': '10.1016/j.inffus.2025.104021', 'type': 'dois'},
#     {'id': '10.1001/jamainternmed.2025.6572', 'type': 'dois'},
#     {'id': '10.4121/e10219cf-4f84-4ff2-843b-5e37068f84b4.v1', 'type': 'dois'},
#     {'id': '10.4121/e10219cf-4f84-4ff2-843b-5e37068f84b4', 'type': 'dois'},
#     {'id': '10.64898/2025.12.04.25341678', 'type': 'dois'},
#     {'id': '10.1186/s12876-025-04564-w', 'type': 'dois'},
#     {'id': '10.21203/rs.3.rs-8419139/v1', 'type': 'dois'},
#     {'id': '10.1016/j.ailsci.2026.100153', 'type': 'dois'},
#     {'id': '10.1007/s13755-025-00424-9', 'type': 'dois'},
#     {'id': '10.21203/rs.3.rs-8312482/v1', 'type': 'dois'}]},
#   'parts': {'data': []},
#   'partOf': {'data': []},
#   'versions': {'data': []},
#   'versionOf': {'data': [{'id': '10.13026/07hj-2a80', 'type': 'dois'}]}}}

# %%
slim_datacite_record(rec)
# Out:
# {'source': 'datacite',
#  'identifiers': [{'identifier': '10.13026/kpb9-mt58',
#    'identifier_type': 'doi'}],
#  'url': 'https://physionet.org/content/mimiciv/3.1/',
#  'title': 'MIMIC-IV',
#  'description': 'Retrospectively collected medical data has the opportunity to improve patient\ncare through knowledge discovery and algorithm development. Broad reuse of\nmedical data is desirable for the greatest public good, but data sharing must\nbe done in a manner which protects patient privacy. Here we present Medical\nInformation Mart for Intensive Care (MIMIC)-IV, a large deidentified dataset\nof patients admitted to the emergency department or an intensive care unit at\nthe Beth Israel Deaconess Medical Center in Boston, MA. MIMIC-IV contains data\nfor over 65,000 patients admitted to an ICU and over 200,000 patients admitted\nto the emergency department. MIMIC-IV incorporates contemporary data and\nadopts a modular approach to data organization, highlighting data provenance\nand facilitating both individual and combined use of disparate data sources.\nMIMIC-IV is intended to carry on the success of MIMIC-III and support a broad\nset of applications within healthcare.',
#  'version': '3.1',
#  'publisher': 'PhysioNet',
#  'created_date': '2024-10-10T21:27:19+00:00',
#  'published_date': '2024-01-20T00:00:00',
#  'creators': [{'name': 'Johnson, Alistair',
#    'affiliations': ['Massachusetts Institute of Technology']},
#   {'name': 'Bulgarelli, Lucas',
#    'affiliations': ['Massachusetts Institute of Technology']},
#   {'name': 'Pollard, Tom',
#    'identifiers': ['https://orcid.org/0000-0002-5676-7898'],
#    'affiliations': ['Massachusetts Institute of Technology, USA']},
#   {'name': 'Gow, Brian',
#    'identifiers': ['https://orcid.org/0000-0002-7682-1943'],
#    'affiliations': ['Massachusetts Institute of Technology']},
#   {'name': 'Moody, Benjamin',
#    'affiliations': ['Massachusetts Institute of Technology']},
#   {'name': 'Horng, Steven',
#    'affiliations': ['Beth Israel Deaconess Medical Center',
#     'Harvard Medical School']},
#   {'name': 'Celi, Leo Anthony',
#    'affiliations': ['Massachusetts Institute of Technology, Cambridge, USA',
#     'Beth Israel Deaconess Medical Center, Boston, USA']},
#   {'name': 'Mark, Roger',
#    'identifiers': ['https://orcid.org/0000-0002-6318-2978'],
#    'affiliations': ['Massachusetts Institute of Technology']}],
#  'citations': {'dois': ['10.1093/jamia/ocae303',
#    '10.1101/2025.02.11.25321833',
#    '10.32628/cseit251112256',
#    '10.2196/preprints.74142',
#    '10.1101/2025.03.26.25324714',
#    '10.1002/alz.14564',
#    '10.1016/j.numecd.2025.103973',
#    '10.1186/s40560-025-00797-9',
#    '10.1089/pmr.2025.0015',
#    '10.7759/cureus.86370',
#    '10.1101/2025.06.26.25330281',
#    '10.1186/s12871-025-03243-3',
#    '10.1007/s40520-025-03115-3',
#    '10.1038/s41598-025-14028-6',
#    '10.21203/rs.3.rs-6680914/v1',
#    '10.1038/s41598-025-12496-4',
#    '10.1101/2025.07.20.25322556',
#    '10.1186/s40779-025-00641-z',
#    '10.1101/2025.08.15.25333725',
#    '10.3389/fphar.2025.1622440',
#    '10.2196/74142',
#    '10.1145/3705328.3748022',
#    '10.1530/ec-25-0377',
#    '10.1093/gigascience/giaf107',
#    '10.1038/s41597-025-05915-8',
#    '10.1016/j.diabres.2025.112105',
#    '10.1186/s13054-025-05642-x',
#    '10.1016/j.jad.2025.120465',
#    '10.1101/2025.08.25.25334266',
#    '10.21203/rs.3.rs-7886784/v1',
#    '10.3389/fcvm.2025.1599318',
#    '10.1016/j.aucc.2025.101489',
#    '10.1186/s12872-025-05231-4',
#    '10.1101/2025.11.11.25340038',
#    '10.1016/j.bja.2025.10.043',
#    '10.1038/s41598-025-26223-6',
#    '10.1177/08850666251358154',
#    '10.1080/15563650.2025.2555970',
#    '10.1016/j.mcna.2025.07.011',
#    '10.1016/j.inffus.2025.104021',
#    '10.1001/jamainternmed.2025.6572',
#    '10.4121/e10219cf-4f84-4ff2-843b-5e37068f84b4.v1',
#    '10.4121/e10219cf-4f84-4ff2-843b-5e37068f84b4',
#    '10.64898/2025.12.04.25341678',
#    '10.1186/s12876-025-04564-w',
#    '10.21203/rs.3.rs-8419139/v1',
#    '10.1016/j.ailsci.2026.100153',
#    '10.1007/s13755-025-00424-9',
#    '10.21203/rs.3.rs-8312482/v1']}}

# %%
doi = "10.1594/PANGAEA.800072"

rec = get_datacite_doi_record(doi)

if rec is None:
    print("No record found.")
else:
    print("Success")
    display(rec)
slim_datacite_record(rec)
# Out:
# Success
# {'id': '10.1594/pangaea.800072',
#  'type': 'dois',
#  'attributes': {'doi': '10.1594/pangaea.800072',
#   'prefix': '10.1594',
#   'suffix': 'pangaea.800072',
#   'identifiers': [],
#   'alternateIdentifiers': [],
#   'creators': [{'name': 'Bose, Trina',
#     'givenName': 'Trina',
#     'familyName': 'Bose',
#     'affiliation': [],
#     'nameIdentifiers': []},
#    {'name': 'Chakraborty, Supriyo',
#     'givenName': 'Supriyo',
#     'familyName': 'Chakraborty',
#     'nameIdentifiers': [{'schemeUri': 'https://orcid.org',
#       'nameIdentifier': 'https://orcid.org/0000-0003-3171-7808',
#       'nameIdentifierScheme': 'ORCID'}],
#     'affiliation': []},
#    {'name': 'Borgaonkar, Hemant',
#     'givenName': 'Hemant',
#     'familyName': 'Borgaonkar',
#     'affiliation': [],
#     'nameIdentifiers': []},
#    {'name': 'Sengupta, Saikat',
#     'givenName': 'Saikat',
#     'familyName': 'Sengupta',
#     'affiliation': [],
#     'nameIdentifiers': []}],
#   'titles': [{'title': 'Reconstructed pCO2 data from tree ring cellulose δ¹³C during 1902-2005 at 10 sites in the Tropics and Northern Subtropics'}],
#   'publisher': 'PANGAEA',
#   'container': {},
#   'publicationYear': 2013,
#   'subjects': [{'subject': 'Event label', 'subjectScheme': 'Parameter'},
#    {'subject': 'Latitude of event', 'subjectScheme': 'Parameter'},
#    {'subject': 'Longitude of event', 'subjectScheme': 'Parameter'},
#    {'subject': 'DATE/TIME', 'subjectScheme': 'Parameter'},
#    {'subject': 'Carbon dioxide, partial pressure',
#     'subjectScheme': 'Parameter'},
#    {'subject': 'Carbon dioxide, partial pressure, model estimation error',
#     'subjectScheme': 'Parameter'},
#    {'subject': 'Reconstructed using tree ring cellulose d13C data',
#     'subjectScheme': 'Method'}],
#   'contributors': [],
#   'dates': [{'date': '2013', 'dateType': 'Issued'}],
#   'language': 'en',
#   'types': {'ris': 'DATA',
#    'bibtex': 'misc',
#    'citeproc': 'dataset',
#    'schemaOrg': 'Dataset',
#    'resourceType': 'Supplementary Dataset',
#    'resourceTypeGeneral': 'Dataset'},
#   'relatedIdentifiers': [{'relationType': 'IsVariantFormOf',
#     'relatedIdentifier': '10013/epic.40264.d003',
#     'relatedIdentifierType': 'Handle'}],
#   'relatedItems': [],
#   'sizes': ['1886 data points'],
#   'formats': ['text/tab-separated-values'],
#   'version': None,
#   'rightsList': [{'rights': 'Creative Commons Attribution 3.0 Unported',
#     'rightsUri': 'https://creativecommons.org/licenses/by/3.0/legalcode',
#     'schemeUri': 'https://spdx.org/licenses/',
#     'rightsIdentifier': 'cc-by-3.0',
#     'rightsIdentifierScheme': 'SPDX'}],
#   'descriptions': [{'description': 'This is the reconstructed pCO2 data from Tree ring cellulose d13C data with estimation errors for 10 sites (location given below) by a geochemical model as given in the publication by Trina Bose, Supriyo Chakraborty, Hemant Borgaonkar, Saikat Sengupta.This data was generated in Stable Isotope Laboratory, Indian Institute of Tropical Meteorology, Pune - 411008, India',
#     'descriptionType': 'Abstract'},
#    {'description': 'Supplement to: Bose, Trina; Chakraborty, Supriyo; Borgaonkar, Hemant; Sengupta, Saikat (2014): Estimation of past atmospheric carbon dioxide levels using tree-ring d13C. Current Science, 107(6), 971-982',
#     'descriptionType': 'Other'}],
#   'geoLocations': [{'geoLocationBox': {'eastBoundLongitude': '78.0',
#      'northBoundLatitude': '68.0',
#      'southBoundLatitude': '-13.0',
#      'westBoundLongitude': '-118.0'}},
#    {'geoLocationPlace': 'Bagrot Valley, Pakistan'},
#    {'geoLocationPlace': 'Boibar Valley, Pakistan'},
#    {'geoLocationPlace': 'Blanco West, California'},
#    {'geoLocationPlace': 'Cavergno, Switzerland'},
#    {'geoLocationPlace': 'Kanasar, Uttaranchal, India'},
#    {'geoLocationPlace': 'Kothi, Himachal Pradesh, India'},
#    {'geoLocationPlace': 'Lötschental, Switzerland'},
#    {'geoLocationPlace': 'Moreju River Valley, Russia'},
#    {'geoLocationPlace': 'Puerto Maldonado, Peru'},
#    {'geoLocationPlace': 'Vigera, Switzerland'}],
#   'fundingReferences': [],
#   'xml': '...',
#   'url': 'https://doi.pangaea.de/10.1594/PANGAEA.800072',
#   'contentUrl': None,
#   'metadataVersion': 16,
#   'schemaVersion': 'http://datacite.org/schema/kernel-4',
#   'source': 'mds',
#   'isActive': True,
#   'state': 'findable',
#   'reason': None,
#   'viewCount': 0,
#   'viewsOverTime': [],
#   'downloadCount': 0,
#   'downloadsOverTime': [],
#   'referenceCount': 0,
#   'citationCount': 0,
#   'citationsOverTime': [],
#   'partCount': 0,
#   'partOfCount': 0,
#   'versionCount': 0,
#   'versionOfCount': 0,
#   'created': '2012-12-11T03:08:04.000Z',
#   'registered': '2012-12-11T03:08:05.000Z',
#   'published': '2013',
#   'updated': '2024-07-13T11:40:23.000Z'},
#  'relationships': {'client': {'data': {'id': 'pangaea.repository',
#     'type': 'clients'}},
#   'provider': {'data': {'id': 'pangaea', 'type': 'providers'}},
#   'media': {'data': {'id': '10.1594/pangaea.800072', 'type': 'media'}},
#   'references': {'data': []},
#   'citations': {'data': []},
#   'parts': {'data': []},
#   'partOf': {'data': []},
#   'versions': {'data': []},
#   'versionOf': {'data': []}}}
# {'source': 'datacite',
#  'identifiers': [{'identifier': '10.1594/pangaea.800072',
#    'identifier_type': 'doi'}],
#  'url': 'https://doi.pangaea.de/10.1594/PANGAEA.800072',
#  'title': 'Reconstructed pCO2 data from tree ring cellulose δ¹³C during 1902-2005 at 10 sites in the Tropics and Northern Subtropics',
#  'subjects': ['Event label',
#   'Latitude of event',
#   'Longitude of event',
#   'DATE/TIME',
#   'Carbon dioxide, partial pressure',
#   'Carbon dioxide, partial pressure, model estimation error',
#   'Reconstructed using tree ring cellulose d13C data'],
#  'description': 'This is the reconstructed pCO2 data from Tree ring cellulose d13C data with estimation errors for 10 sites (location given below) by a geochemical model as given in the publication by Trina Bose, Supriyo Chakraborty, Hemant Borgaonkar, Saikat Sengupta.This data was generated in Stable Isotope Laboratory, Indian Institute of Tropical Meteorology, Pune - 411008, India',
#  'publisher': 'PANGAEA',
#  'created_date': '2012-12-11T03:08:04+00:00',
#  'publication_date': '2013-01-01T00:00:00',
#  'creators': [{'name': 'Bose, Trina'},
#   {'name': 'Chakraborty, Supriyo',
#    'identifiers': ['https://orcid.org/0000-0003-3171-7808']},
#   {'name': 'Borgaonkar, Hemant'},
#   {'name': 'Sengupta, Saikat'}]}

# %% [markdown]
# ### Valid DOI not found in DataCite

# %%
doi = "https://doi.org/10.1038/s42255-024-01165-x"

rec = get_datacite_doi_record(doi)

if rec is None:
    print("No record found.")
else:
    print("Success")
    display(rec)
# Out:
# No record found.

# %% [markdown]
# ## Write records to ndjson for list of DOIs

# %%
dois = [
    "10.13026/kpb9-mt58",
    "10.60775/fairhub.2"
]

out_dir = Path("output/datacite/harvest_doi_list_test")
out_dir.mkdir(parents=True, exist_ok=True)

harvest_datacite_doi_list_to_ndjson(
    doi_list=dois,
    output_folder=str(out_dir),
    batch_size=2,
)

print(f"Done. Check: {out_dir.resolve()}")
# Out:
# Fetching 10.13026/kpb9-mt58 ...
# Fetching 10.60775/fairhub.2 ...
#   Writing 2 metadata records → output\datacite\harvest_doi_list_test\datacite-batch-0000.ndjson
# Done. Check: C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\harvest_doi_list_test

# %%
dois = [
    "10.13026/kpb9-mt58",
    "https://fairhub.io/datasets/2", # not a DOI should give an error
    "10.60775/fairhub.2"
]

out_dir = Path("output/datacite/harvest_doi_list_test")
out_dir.mkdir(parents=True, exist_ok=True)

harvest_datacite_doi_list_to_ndjson(
    doi_list=dois,
    output_folder=str(out_dir),
    batch_size=2,
)

print(f"Done. Check: {out_dir.resolve()}")
# Out:
# Fetching 10.13026/kpb9-mt58 ...
# Fetching https://fairhub.io/datasets/2 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 10
#       7 out_dir = Path("output/datacite/harvest_doi_list_test")
#       8 out_dir.mkdir(parents=True, exist_ok=True)
# ---> 10 harvest_datacite_doi_list_to_ndjson(
#      11     doi_list=dois,
#      12     output_folder=str(out_dir),
#      13     batch_size=2,
#      14 )
#      16 print(f"Done. Check: {out_dir.resolve()}")
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\datacite\jobs.py:62, in harvest_datacite_doi_list_to_ndjson(doi_list, output_folder, batch_size)
#      59 for doi in doi_list:
#      60     print(f"Fetching {doi} ...")
# ---> 62     metadata = get_datacite_doi_record(doi, session=session)
#      63     if metadata is None:
#      64         print(f"  No DataCite record found for {doi}")
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\datacite\discovery.py:36, in get_datacite_doi_record(doi, session)
#      34 norm_doi = _norm_doi(doi)
#      35 if not norm_doi:
# ---> 36     raise ValueError(f"Invalid DOI: {doi}")
#      38 s = session or make_session(allowed_methods=("GET",))
#      39 return get_datacite_record_by_norm_doi(norm_doi, session=s)
#
# ValueError: Invalid DOI: https://fairhub.io/datasets/2

# %%
dois = [
    "10.13026/kpb9-mt58",
    "10.60775/fairhub.2"
]

out_dir = Path("output/datacite/harvest_doi_list_test")
out_dir.mkdir(parents=True, exist_ok=True)

harvest_datacite_doi_list_to_ndjson(
    doi_list=dois,
    output_folder=str(out_dir),
    batch_size=1,
)

print(f"Done. Check: {out_dir.resolve()}")
# Out:
# Fetching 10.13026/kpb9-mt58 ...
#   Writing 1 metadata records → output\datacite\harvest_doi_list_test\datacite-batch-0000.ndjson
# Fetching 10.60775/fairhub.2 ...
#   Writing 1 metadata records → output\datacite\harvest_doi_list_test\datacite-batch-0001.ndjson
# Done. Check: C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\harvest_doi_list_test

# %% [markdown]
# ## Write records to ndjson for date range

# %%
start_date_str = "2014-12-28"
end_date_str = "2015-01-10"

out_dir = Path("output/datacite/harvest_date_range_test")
out_dir.mkdir(parents=True, exist_ok=True)

n = harvest_datacite_datasets_for_date_range_to_ndjson(
    start_date_str=start_date_str,
    end_date_str=end_date_str,
    window_days=7,          # default, but explicit for the test
    page_size=1000,
    save_folder=str(out_dir),
    skip_empty_files=True,
    polite_sleep_seconds=0.5,
)

print(f"Done. Wrote {n:,} records across window files in {out_dir.resolve()}")
# Out:
# Fetching records 2015-01-04 → 2015-01-10 (window_days=7, page_size=1000)
#   Saved 2471 records → output\datacite\harvest_date_range_test\datacite-2015-01-04-2015-01-10.ndjson
# Fetching records 2015-01-01 → 2015-01-03 (window_days=7, page_size=1000)
#   Saved 787 records → output\datacite\harvest_date_range_test\datacite-2015-01-01-2015-01-03.ndjson
# Fetching records 2014-12-28 → 2014-12-31 (window_days=7, page_size=1000)
#   Saved 828 records → output\datacite\harvest_date_range_test\datacite-2014-12-28-2014-12-31.ndjson
# Finished harvest. Total records saved: 4086
# Done. Wrote 4,086 records across window files in C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\harvest_date_range_test

# %% [markdown]
# ## Write batch slim records

# %%
# Folder containing raw DataCite NDJSON or NDJSON.GZ files
src_folder = Path("output/datacite/harvest_date_range_test")

# Folder where slimmed outputs will be written
dst_folder = Path("output/datacite/batch_slim_test")

# Safety checks
if not src_folder.exists():
    raise FileNotFoundError(
        f"Source folder does not exist: {src_folder.resolve()}"
    )

dst_folder.mkdir(parents=True, exist_ok=True)

print("Running DataCite batch slimming test")
print(f"  Input folder : {src_folder.resolve()}")
print(f"  Output folder: {dst_folder.resolve()}")
print("---")

# Run the batch slim function
summary = batch_slim_datacite_record_to_ndjson(
    src_folder=str(src_folder),
    dst_folder=str(dst_folder),
    overwrite=True,          # overwrite for repeatable tests
    accept_gz=True,
    one_line_progress=False, # easier to read in logs
)

# Summary
print("\nSummary:")
for k, v in summary.items():
    print(f"  {k}: {v}")

print("\nTest completed successfully.")
# Out:
# Running DataCite batch slimming test
#   Input folder : C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\harvest_date_range_test
#   Output folder: C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\batch_slim_test
# ---
# Done. files=3 kept=4,086 bad=0 time=1.2s rate≈3,413/s → C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\batch_slim_test
#
# Summary:
#   files_seen: 3
#   records_read: 4086
#   records_kept: 4086
#   records_bad_json: 0
#   output_dir: C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\batch_slim_test
#   elapsed_sec: 1.2
#   rate_rec_per_sec: 3413
#
# Test completed successfully.
