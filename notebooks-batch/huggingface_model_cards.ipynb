# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from sindex.sources.huggingface.jobs import scan_hfhub_modelcards

# %% [markdown]
# ## Get DOI and EMDB mentions in model cards (YAML header of README files only)

# %%
HF_TOKEN = os.environ.get('HF_TOKEN')

# %%
scan_hfhub_modelcards(limit=100, token=HF_TOKEN)
# Out:
# Loading history log...
# Loaded 36 previously scanned models.
# Connecting to Hugging Face Hub
#
# Processing complete. Scanned 64 new models.
