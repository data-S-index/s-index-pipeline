# %%
# %load_ext autoreload
# %autoreload 2
from sindex.sources.mdc.jobs import batch_find_citations_mdc_ducbb_optimized
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
mdc_path = os.path.join(parent_dir, "input", "mdc")
#mdc_path = r"input\mdc-light"
db_path = os.path.join(mdc_path, "mdc_index.duckdb")

# %%
slim_folder = ""
out_ndjson = 
batch_find_citations_mdc_ducbb_optimized
