# %% [markdown]
# # MDC Citations for 50M DOIs datasets from DataCite

# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2
from sindex.sources.mdc.jobs import batch_find_citations_mdc_ducdb_optimized
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
mdc_path = os.path.join(parent_dir, "input", "mdc")
#mdc_path = r"input\mdc-light"
db_path = os.path.join(mdc_path, "mdc_index.duckdb")

# %% [markdown]
# ## Test

# %%
# Test
slim_folder = r"C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\input\demo_datasets_slim_metadata_ndjson"
out_ndjson = r"C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks-batch\output\mdc\mdc_demo.ndjson"
batch_find_citations_mdc_ducdb_optimized(slim_folder, out_ndjson, db_path)
# Out:
# Citations matched: 6 | Elapsed: 0.09s
# Processing complete. Output saved to C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks-batch\output\mdc\mdc_demo.ndjson
# Total citations matched: 6

# %% [markdown]
# ## Actual batch

# %% [markdown]
# ### DataCite (DOIs)

# %%
slim_folder = r"I:\pipeline-data\records\slim-records\datacite-slim-records"
out_ndjson = r"I:\pipeline-data\citations\mdc\mdc_citations.ndjson"

# %%
batch_find_citations_mdc_ducdb_optimized(slim_folder, out_ndjson, db_path)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Citations matched: 1,465,361 | Elapsed: 2547.85s
# Processing complete. Output saved to I:\pipeline-data\citations\mdc\mdc_citations.json
# Total citations matched: 1,465,361

# %% [markdown]
# ### EMDB

# %%
slim_folder = r"I:\pipeline-data\records\slim-records\emdb-slim-records"
out_ndjson = r"I:\pipeline-data\citations\mdc\mdc_citations_emdb.ndjson"

# %%
batch_find_citations_mdc_ducdb_optimized(slim_folder, out_ndjson, db_path)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Citations matched: 15,134 | Elapsed: 10.41s
# Processing complete. Output saved to I:\pipeline-data\citations\mdc\mdc_citations_emdb.json
# Total citations matched: 15,134
