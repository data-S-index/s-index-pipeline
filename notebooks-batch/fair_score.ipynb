# %%
from sindex.sources.fuji.jobs import batch_fair_evaluation_report

# %%
emdb_slim_folder = "input"
output = "fair_score_emdb.ndjson"
batch_fair_evaluation_report(emdb_slim_folder, output)
# Out:
# Starting batch process on 1 files...
# [File 1/1] Processed: 7 | Errors: 0 | Current: emdb-records-slim.nd...

# %% [markdown]
# ## Rerun for SPARC datasets

# %% [markdown]
# ### Get records of only sparc datasets

# %%
from sindex.utils.files import filter_ndjson_by_identifier_prefix

# %%
ndjson_folder = r"D:\pipeline-data\records\slim-records\datacite-slim-records"
output_file = r"D:\may-2026-data\sparc-slim-records.ndjson"
prefix = "10.26275"

# %%
filter_ndjson_by_identifier_prefix(
    input_folder=ndjson_folder,
    output_file=output_file,
    prefix=prefix
)
# Out:
# Found 491 NDJSON files in 'D:\pipeline-data\records\slim-records\datacite-slim-records'
# Processed: 491/491 files | Matches: 785
# Done. 793 matching records written to 'D:\may-2026-data\sparc-slim-records.ndjson'
# 793

# %% [markdown]
# ### Run batch FAIR scores

# %%
sparc_folder = r"D:\may-2026-data"
output = r"D:\may-2026-data\new_fair_scores\fair_score_sparc.ndjson"
batch_fair_evaluation_report(sparc_folder, output)
# Out:
# Starting batch process on 1 files...
# [File 1/1] Processed: 793 | Errors: 2 | Current: sparc-slim-records.n...
#
# Processing Complete!
# Successes saved to: D:\may-2026-data\new_fair_scores\fair_score_sparc.ndjson
# Errors saved to:    C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-batch\fair_errors_20260522-141342.ndjson
