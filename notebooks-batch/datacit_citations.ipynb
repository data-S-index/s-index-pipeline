# %% [markdown]
# ## Import

# %%
from sindex.sources.datacite.jobs import find_citations_dc_slim_metadata

# %% [markdown]
# ## Test small batch

# %%
slim_folder = r"C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-batch\input\datacite_slim_example"
out_ndjson = r"C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-batch\output\datacite_citations\citations_example.ndjson"
find_citations_dc_slim_metadata(slim_folder, out_ndjson)
# Out:
# [Progress] files 1/1 completed | rows 2 | edges 36 | bad_json 0
# {'files': 1, 'rows_read': 2, 'edges_written': 36, 'bad_json_lines': 0}

# %% [markdown]
# ## Test actual slim metadata files

# %%
slim_folder = r"D:\pipeline-data\slim-records\datacite-slim-records"
out_ndjson = r"C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-batch\output\datacite_citations\citations_dc_no_date.ndjson"
find_citations_dc_slim_metadata(slim_folder, out_ndjson)
# Out:
# [Progress] files 161/771 completed | rows 717,502 | edges 0 | bad_json 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 slim_folder = r"D:\pipeline-data\slim-records\datacite-slim-records"
#       2 out_ndjson = r"C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-batch\output\datacite_citations\citations_dc_no_date.ndjson"
# ----> 3 find_citations_dc_slim_metadata(slim_folder, out_ndjson)
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\datacite\jobs.py:412, in find_citations_dc_slim_metadata(slim_folder, out_ndjson, pattern, recursive, dataset_id_as_url, print_errors)
#     410 with open(out_ndjson, "wt", encoding="utf-8") as out:
#     411     for i, fp in enumerate(files, start=1):
# --> 412         for rec, err in _iter_json_lines(Path(fp)):
#     413             if err:
#     414                 n_bad_json += 1
#
# ...
