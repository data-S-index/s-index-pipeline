# %% [markdown]
# Most of the work is done using the Software Heritage Graph Dataset on AWS
# We just enrich the mentions with weight here to create the final standard mentions ndjson file

# %%
# %load_ext autoreload
# %autoreload 2

from sindex.sources.swh.normalize import enrich_swh_base_mentions
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
enrich_swh_base_mentions(
    db_path=r"D:\pipeline-data\records\slim-records\datacite-slim-records.duckdb",
    input_ndjson=r"D:\pipeline-data\mentions\swh\data\base_mentions.ndjson",
    output_ndjson=r"D:\pipeline-data\mentions\swh\swh-mentions.ndjson",
)
# Out:
# Enriching records from D:\pipeline-data\mentions\swh\data\base_mentions.ndjson...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Done! Enriched 41592 lines to D:\pipeline-data\mentions\swh\data\swh-mentions.ndjson
# 41592
