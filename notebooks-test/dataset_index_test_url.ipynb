# %% [markdown]
# # Test dataset index calculation for URL

# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sindex.metrics.jobs import dataset_index_series_from_url

# %% [markdown]
# ## Tests

# %% [markdown]
# ### Validate dataset URL available in MDC

# %%
url = "https://ghdx.healthdata.org/lbd-data"
dataset_report = dataset_index_series_from_url(url)
display(dataset_report)
# Out:
# {'input_url': 'https://ghdx.healthdata.org/lbd-data',
#  'norm_url': 'https://ghdx.healthdata.org/lbd-data',
#  'input_identifier': None,
#  'norm_identifier': '',
#  'metadata': None,
#  'topic': None,
#  'fair': {'fair_score': 11.54,
#   'evaluation_date': '2026-02-10T01:46:26+00:00',
#   'fuji_metric_version': '0.8',
#   'fuji_software_version': '3.5.1'},
#  'citations': [{'dataset_id': 'https://ghdx.healthdata.org/lbd-data',
#    'citation_link': 'https://doi.org/10.1136/bmjgh-2021-005238',
#    'source': ['mdc'],
#    'citation_year': 2021,
#    'citation_date': '2021-06-01T00:00:00+00:00',
#    'placeholder_year': False,
#    'placeholder_date': False,
#    'citation_weight': 1.0}],
#  'mentions': None,
#  'normalization_factors': {'FT': 13.46,
#   'CTw': 1.0,
#   'MTw': 1.0,
#   'n_year_gap': None,
#   'method': 'Default'},
#  'dataset_index_series': [{'year': 2021, 'dataset_index': 0.6191183754333828}]}

# %%
url = "https://ghdx.healthdata.org/lbd-data"
pubyear = 2020
dataset_report = dataset_index_series_from_url(url, pubyear=pubyear)
display(dataset_report)
# Out:
# {'input_url': 'https://ghdx.healthdata.org/lbd-data',
#  'norm_url': 'https://ghdx.healthdata.org/lbd-data',
#  'input_identifier': None,
#  'norm_identifier': '',
#  'metadata': None,
#  'topic': None,
#  'fair': {'fair_score': 11.54,
#   'evaluation_date': '2026-02-10T01:47:57+00:00',
#   'fuji_metric_version': '0.8',
#   'fuji_software_version': '3.5.1'},
#  'citations': [{'dataset_id': 'https://ghdx.healthdata.org/lbd-data',
#    'citation_link': 'https://doi.org/10.1136/bmjgh-2021-005238',
#    'source': ['mdc'],
#    'citation_year': 2021,
#    'citation_date': '2021-06-01T00:00:00+00:00',
#    'placeholder_year': False,
#    'placeholder_date': False,
#    'citation_weight': 1.23}],
#  'mentions': None,
#  'normalization_factors': {'FT': 13.46,
#   'CTw': 1.0,
#   'MTw': 1.0,
#   'n_year_gap': None,
#   'method': 'Default'},
#  'dataset_index_series': [{'year': 2020, 'dataset_index': 0.28578504210004946},
#   {'year': 2021, 'dataset_index': 0.6957850421000495}]}

# %%
url = "https://ghdx.healthdata.org/lbd-data"
pubdate = "2020-01-15"
subfield_id = "2731"
dataset_report = dataset_index_series_from_url(url, pubyear = pubyear, subfield_id = subfield_id)
display(dataset_report)
# Out:
# {'input_url': 'https://ghdx.healthdata.org/lbd-data',
#  'norm_url': 'https://ghdx.healthdata.org/lbd-data',
#  'input_identifier': None,
#  'norm_identifier': '',
#  'metadata': None,
#  'topic': {'subfield_id': '2731'},
#  'fair': {'fair_score': 11.54,
#   'evaluation_date': '2026-02-10T02:21:26+00:00',
#   'fuji_metric_version': '0.8',
#   'fuji_software_version': '3.5.1'},
#  'citations': [{'dataset_id': 'https://ghdx.healthdata.org/lbd-data',
#    'citation_link': 'https://doi.org/10.1136/bmjgh-2021-005238',
#    'source': ['mdc'],
#    'citation_year': 2021,
#    'citation_date': '2021-06-01T00:00:00+00:00',
#    'placeholder_year': False,
#    'placeholder_date': False,
#    'citation_weight': 1.23}],
#  'mentions': None,
#  'normalization_factors': {'FT': 13.46,
#   'CTw': 1.0,
#   'MTw': 1.0,
#   'n_year_gap': 0,
#   'method': 'Exact Year'},
#  'dataset_index_series': [{'year': 2020, 'dataset_index': 0.28578504210004946},
#   {'year': 2021, 'dataset_index': 0.6957850421000495}]}

# %% [markdown]
# ### DOI (not URL)

# %%
doi = "10.13026/kpb9-mt58" 
dataset_report = dataset_index_series_from_url(doi)
display(dataset_report)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 doi = "10.13026/kpb9-mt58"
# ----> 2 dataset_report = dataset_index_series_from_url(doi)
#       3 display(dataset_report)
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\metrics\jobs.py:15, in dataset_index_series_from_url(url, identifier, pubyear, subfield_id, subfield_name)
#      13 from sindex.sources.datacite.discovery import get_datacite_doi_record
#      14 from sindex.sources.datacite.jobs import find_citations_dc_from_citation_block
# ---> 15 from sindex.sources.datacite.normalize import slim_datacite_record
#      16 from sindex.sources.fuji.jobs import fair_evaluation_report
#      17 from sindex.sources.github.discovery import find_github_mentions_for_dataset_id
#
# ValueError: Invalid URL format: 10.13026/kpb9-mt58 (must start with http:// or https://)

# %% [markdown]
# ### Valid DOI URL

# %%
doi = "https://doi.org/10.1038/s42255-024-01165-x" 
dataset_report = dataset_index_series_from_url(doi)
display(dataset_report)
# Out:
# {'input_url': 'https://doi.org/10.1038/s42255-024-01165-x',
#  'norm_url': '10.1038/s42255-024-01165-x',
#  'input_identifier': None,
#  'norm_identifier': '',
#  'metadata': None,
#  'topic': None,
#  'fair': {'fair_score': 73.08,
#   'evaluation_date': '2026-02-10T02:23:01+00:00',
#   'fuji_metric_version': '0.8',
#   'fuji_software_version': '3.5.1'},
#  'citations': None,
#  'mentions': [{'dataset_id': 'https://doi.org/10.1038/s42255-024-01165-x',
#    'mention_link': 'https://github.com/DrDavidL/multimodal-health-risk-communicator',
#    'source': ['github'],
#    'mention_year': 2026,
#    'mention_date': '2026-01-23T03:40:06+00:00',
#    'placeholder_year': False,
#    'placeholder_date': False,
#    'mention_weight': 1.0}],
#  'normalization_factors': {'FT': 13.46,
#   'CTw': 1.0,
#   'MTw': 1.0,
#   'n_year_gap': None,
#   'method': 'Default'},
#  'dataset_index_series': [{'year': 2026, 'dataset_index': 2.143140168400198}]}
