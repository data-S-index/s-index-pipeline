# %% [markdown]
# # Test GitHub mentions finding code

# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sindex.sources.github.discovery import find_github_mentions_for_dataset_id 
from sindex.sources.github.jobs import (
    harvest_github_mentions_from_slim_ndjson_to_ndjson,
    )
from sindex.metrics.mentions import merge_mentions_dicts
from pathlib import Path

# %% [markdown]
# ## Find GitHub mentions for one dataset id

# %% [markdown]
# ### With DOI and pub year

# %%
dataset_id = "10.13026/kpb9-mt58"
pubyear = 2024
find_github_mentions_for_dataset_id(dataset_id, dataset_pubyear = pubyear)
# Out:
# [{'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
#   'mention_link': 'https://github.com/CUB-CORR/reprodICU',
#   'mention_weight': 1.23,
#   'mention_date': '2025-04-29T17:10:26+00:00',
#   'placeholder_date': False,
#   'mention_year': 2025,
#   'placeholder_year': False},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
#   'mention_link': 'https://github.com/Crazz-Zaac/informative-missingness',
#   'mention_weight': 1.23,
#   'mention_date': '2025-05-09T09:32:17+00:00',
#   'placeholder_date': False,
#   'mention_year': 2025,
#   'placeholder_year': False},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
#   'mention_link': 'https://github.com/Mammalian-Associate/Health-Informatics-Project',
#   'mention_weight': 1.23,
#   'mention_date': '2025-03-10T23:04:22+00:00',
#   'placeholder_date': False,
#   'mention_year': 2025,
#   'placeholder_year': False},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
# ...

# %% [markdown]
# ### With DOI and no pubyear

# %%
dataset_id = "10.13026/kpb9-mt58"
mentions1 = find_github_mentions_for_dataset_id(dataset_id)

# %%
display(mentions1)
# Out:
# [{'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
#   'mention_link': 'https://github.com/CUB-CORR/reprodICU',
#   'mention_weight': 1.0,
#   'mention_date': '2025-04-29T17:10:26+00:00',
#   'placeholder_date': False,
#   'mention_year': 2025,
#   'placeholder_year': False},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
#   'mention_link': 'https://github.com/Crazz-Zaac/informative-missingness',
#   'mention_weight': 1.0,
#   'mention_date': '2025-05-09T09:32:17+00:00',
#   'placeholder_date': False,
#   'mention_year': 2025,
#   'placeholder_year': False},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
#   'mention_link': 'https://github.com/Mammalian-Associate/Health-Informatics-Project',
#   'mention_weight': 1.0,
#   'mention_date': '2025-03-10T23:04:22+00:00',
#   'placeholder_date': False,
#   'mention_year': 2025,
#   'placeholder_year': False},
#  {'dataset_id': '10.13026/kpb9-mt58',
#   'source': ['github'],
# ...

# %% [markdown]
# ### With EMDB ID and pubyear

# %%
dataset_id = "EMD-24511"
pubyear = 2021
find_github_mentions_for_dataset_id(dataset_id, dataset_pubyear = pubyear)
# Out:
# []

# %% [markdown]
# ### With some url

# %%
dataset_id = "https://fairdataihub.org"
mentions2 = find_github_mentions_for_dataset_id(dataset_id)
display(mentions2)
# Out:
# [{'dataset_id': 'https://fairdataihub.org',
#   'source': ['github'],
#   'mention_link': 'https://github.com/AI-READI/DataElementMaps',
#   'mention_weight': 1.0,
#   'mention_date': '2023-06-28T18:18:31+00:00',
#   'placeholder_date': False,
#   'mention_year': 2023,
#   'placeholder_year': False},
#  {'dataset_id': 'https://fairdataihub.org',
#   'source': ['github'],
#   'mention_link': 'https://github.com/AI-READI/ai-readi-docs',
#   'mention_weight': 1.0,
#   'mention_date': '2024-02-13T20:54:42+00:00',
#   'placeholder_date': False,
#   'mention_year': 2024,
#   'placeholder_year': False},
#  {'dataset_id': 'https://fairdataihub.org',
#   'source': ['github'],
#   'mention_link': 'https://github.com/AI-READI/ai-readi-notebooks',
#   'mention_weight': 1.0,
#   'mention_date': '2025-04-22T23:23:25+00:00',
#   'placeholder_date': False,
#   'mention_year': 2025,
#   'placeholder_year': False},
#  {'dataset_id': 'https://fairdataihub.org',
#   'source': ['github'],
# ...
