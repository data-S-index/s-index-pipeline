# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import duckdb
from sindex.metrics.normalization import get_subfield_year_norm_factors

# %% [markdown]
# ## Tests

# %%
db = "input/subfield_norm_factors.duckdb"
subfield_id = "2731"
pubyear = 2028

# %%
get_subfield_year_norm_factors(db, subfield_id, pubyear)
# Out:
# {'FT': 13.46,
#  'CTw': 1.0,
#  'MTw': 1.0,
#  'n_year_gap': 1,
#  'method': 'Closest Past Year'}

# %%
get_subfield_year_norm_factors(db, None, None)
# Out:
# {'FT': 13.46, 'CTw': 1.0, 'MTw': 1.0, 'n_year_gap': None, 'method': 'Default'}
