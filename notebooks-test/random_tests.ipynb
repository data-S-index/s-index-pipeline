# %%
from sindex.core.dates import _norm_date_iso
import os
import json

# %% [markdown]
# ## Check _norm_date_iso output

# %%
_norm_date_iso("2024")
# Out:
# '2024-01-01T00:00:00'

# %%
_norm_date_iso("2024-05")
# Out:
# '2024-05-01T00:00:00'

# %%
_norm_date_iso("2024-4")
# Out:
# '2024-04-01T00:00:00'

# %%
_norm_date_iso("2024-4-43")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\sindex\Lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\envs\sindex\Lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\core\dates.py:64, in _norm_date_iso(s)
#      63 try:
# ...
