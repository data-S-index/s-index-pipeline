# %% [markdown]
# # Test DataCite dataset harvesting code

# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path

from sindex.sources.datacite.discovery import get_datacite_doi_record
from sindex.sources.datacite.jobs import (
    batch_slim_datacite_record_to_ndjson,
    harvest_datacite_datasets_for_date_range_to_ndjson
)
from sindex.sources.datacite.normalize import slim_datacite_record

# %% [markdown]
# ## Get record for single DOI and create slim metadata

# %% [markdown]
# ### Valid DOI found in DataCite

# %%
doi = "10.13026/kpb9-mt58"
doi = "10.17026/dans-xue-sfxp"
rec = get_datacite_doi_record(doi)

if rec is None:
    print("No record found.")
else:
    print("Success")
    display(rec)
# Out:
# Success
# {'id': '10.17026/dans-xue-sfxp',
#  'type': 'dois',
#  'attributes': {'doi': '10.17026/dans-xue-sfxp',
#   'prefix': '10.17026',
#   'suffix': 'dans-xue-sfxp',
#   'identifiers': [{'identifier': 'easy-dataset:228383',
#     'identifierType': ':unav'}],
#   'alternateIdentifiers': [{'alternateIdentifierType': ':unav',
#     'alternateIdentifier': 'easy-dataset:228383'}],
#   'creators': [{'name': 'Bureau voor Archeologie',
#     'nameType': 'Personal',
#     'affiliation': [],
#     'nameIdentifiers': []}],
#   'titles': [{'title': 'Karstraat 21-25, Bemmel, gemeente Lingewaard: een bureau- en inventariserend veldonderzoek in de vorm van boringen in de verkennende en karterende fase'}],
#   'publisher': 'DANS Data Station Archaeology',
#   'container': {},
#   'publicationYear': 2020,
#   'subjects': [{'subject': 'Arts and Humanities'}],
#   'contributors': [{'name': 'A. G. Boer, de',
#     'nameType': 'Personal',
#     'givenName': 'de',
#     'familyName': 'A. G. Boer',
#     'affiliation': ['Bureau voor Archeologie'],
#     'contributorType': 'ContactPerson',
#     'nameIdentifiers': []}],
#   'dates': [{'date': '2023-11-24', 'dateType': 'Issued'},
#    {'date': '2020-04-29', 'dateType': 'Created'},
#    {'date': '2021-11-24', 'dateType': 'Submitted'},
#    {'date': '2020-04-29', 'dateType': 'Available'},
#    {'date': '2020-04-28', 'dateType': 'Updated'}],
#   'language': 'nl',
#   'types': {'ris': 'DATA',
#    'bibtex': 'misc',
#    'citeproc': 'dataset',
#    'schemaOrg': 'Dataset',
#    'resourceTypeGeneral': 'Dataset'},
#   'relatedIdentifiers': [{'relationType': 'IsSupplementTo',
#     'relatedIdentifier': '2214-6687',
#     'relatedIdentifierType': 'ISSN'}],
#   'relatedItems': [],
#   'sizes': ['28441',
#    '2849280',
#    '2985984',
#    '2916352',
#    '2953728',
#    '2874368',
#    '2903040',
#    '4195435',
#    '3059712',
#    '2817024',
#    '2714624',
#    '2952192',
#    '2874880',
#    '2863104',
#    '2872320',
#    '3094528',
#    '2885632',
#    '2889728',
#    '2998272',
#    '3084800',
#    '45845',
#    '2970112',
#    '2819584',
#    '2964992',
#    '3064832',
#    '2928640',
#    '2919936',
#    '27683'],
#   'formats': ['application/zip',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'application/pdf',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'text/html',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'image/jpeg',
#    'application/zip'],
#   'version': '2.0',
#   'rightsList': [{'rightsUri': 'info:eu-repo/semantics/openAccess'},
#    {'rights': 'Creative Commons Zero v1.0 Universal',
#     'rightsUri': 'https://creativecommons.org/publicdomain/zero/1.0/legalcode',
#     'schemeUri': 'https://spdx.org/licenses/',
#     'rightsIdentifier': 'cc0-1.0',
#     'rightsIdentifierScheme': 'SPDX'}],
#   'descriptions': [{'description': '&lt;p&gt;Bureau voor Archeologie heeft een bureau- en inventariserend veldonderzoek in de vorm van boringen uitgevoerd voor sloop- en bouwwerkzaamheden aan de Karstraat 21-25 te Bemmel.&lt;/p&gt;',
#     'descriptionType': 'Abstract'},
#    {'description': 'Date Submitted: 2021-11-24',
#     'descriptionType': 'Abstract'}],
#   'geoLocations': [],
#   'fundingReferences': [],
#   'xml': '...',
#   'url': 'https://archaeology.datastations.nl/citation?persistentId=doi:10.17026/DANS-XUE-SFXP',
#   'contentUrl': None,
#   'metadataVersion': 5,
#   'schemaVersion': 'http://datacite.org/schema/kernel-4',
#   'source': 'mds',
#   'isActive': True,
#   'state': 'findable',
#   'reason': None,
#   'viewCount': 0,
#   'viewsOverTime': [],
#   'downloadCount': 0,
#   'downloadsOverTime': [],
#   'referenceCount': 0,
#   'citationCount': 0,
#   'citationsOverTime': [],
#   'partCount': 0,
#   'partOfCount': 0,
#   'versionCount': 0,
#   'versionOfCount': 0,
#   'created': '2021-11-30T09:48:53.000Z',
#   'registered': '2021-11-30T09:48:53.000Z',
#   'published': '2020',
#   'updated': '2025-07-03T19:43:13.000Z'},
#  'relationships': {'client': {'data': {'id': 'dans.archive',
#     'type': 'clients'}},
#   'provider': {'data': {'id': 'dans', 'type': 'providers'}},
#   'media': {'data': {'id': '10.17026/dans-xue-sfxp', 'type': 'media'}},
#   'references': {'data': []},
#   'citations': {'data': []},
#   'parts': {'data': []},
#   'partOf': {'data': []},
#   'versions': {'data': []},
#   'versionOf': {'data': []}}}

# %%
slim_datacite_record(rec)
# Out:
# {'source': 'datacite',
#  'identifiers': [{'identifier': '10.17026/dans-xue-sfxp',
#    'identifier_type': 'doi'}],
#  'url': 'https://archaeology.datastations.nl/citation?persistentId=doi:10.17026/DANS-XUE-SFXP',
#  'title': 'Karstraat 21-25, Bemmel, gemeente Lingewaard: een bureau- en inventariserend veldonderzoek in de vorm van boringen in de verkennende en karterende fase',
#  'subjects': ['Arts and Humanities'],
#  'description': '&lt;p&gt;Bureau voor Archeologie heeft een bureau- en inventariserend veldonderzoek in de vorm van boringen uitgevoerd voor sloop- en bouwwerkzaamheden aan de Karstraat 21-25 te Bemmel.&lt;/p&gt;',
#  'version': '2.0',
#  'publisher': 'DANS Data Station Archaeology',
#  'doi_created_date': '2021-11-30T09:48:53.000Z',
#  'issued': '2023-11-24',
#  'created': '2020-04-29',
#  'published': '2020',
#  'publication_year': 2020,
#  'pubyear': 2020,
#  'publication_date': '2020-01-01T00:00:00',
#  'creators': [{'name': 'Bureau voor Archeologie', 'name_type': 'Personal'}]}

# %% [markdown]
# ### Valid DOI not found in DataCite

# %%
doi = "https://doi.org/10.1038/s42255-024-01165-x"

rec = get_datacite_doi_record(doi)

if rec is None:
    print("No record found.")
else:
    print("Success")
    display(rec)
# Out:
# No record found.

# %%
dois = ["10.13026/kpb9-mt58", "10.60775/fairhub.2"]

out_dir = Path("output/datacite/harvest_doi_list_test")
out_dir.mkdir(parents=True, exist_ok=True)

harvest_datacite_doi_list_to_ndjson(
    doi_list=dois,
    output_folder=str(out_dir),
    batch_size=2,
)

print(f"Done. Check: {out_dir.resolve()}")
# Out:
# Fetching 10.13026/kpb9-mt58 ...
# Fetching 10.60775/fairhub.2 ...
#   Writing 2 metadata records → output\datacite\harvest_doi_list_test\datacite-batch-0000.ndjson
# Done. Check: C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\harvest_doi_list_test

# %%
dois = [
    "10.13026/kpb9-mt58",
    "https://fairhub.io/datasets/2",  # not a DOI should give an error
    "10.60775/fairhub.2",
]

out_dir = Path("output/datacite/harvest_doi_list_test")
out_dir.mkdir(parents=True, exist_ok=True)

harvest_datacite_doi_list_to_ndjson(
    doi_list=dois,
    output_folder=str(out_dir),
    batch_size=2,
)

print(f"Done. Check: {out_dir.resolve()}")
# Out:
# Fetching 10.13026/kpb9-mt58 ...
# Fetching https://fairhub.io/datasets/2 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 10
#       7 out_dir = Path("output/datacite/harvest_doi_list_test")
#       8 out_dir.mkdir(parents=True, exist_ok=True)
# ---> 10 harvest_datacite_doi_list_to_ndjson(
#      11     doi_list=dois,
#      12     output_folder=str(out_dir),
#      13     batch_size=2,
#      14 )
#      16 print(f"Done. Check: {out_dir.resolve()}")
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\datacite\jobs.py:62, in harvest_datacite_doi_list_to_ndjson(doi_list, output_folder, batch_size)
#      59 for doi in doi_list:
#      60     print(f"Fetching {doi} ...")
# ---> 62     metadata = get_datacite_doi_record(doi, session=session)
#      63     if metadata is None:
#      64         print(f"  No DataCite record found for {doi}")
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\datacite\discovery.py:36, in get_datacite_doi_record(doi, session)
#      34 norm_doi = _norm_doi(doi)
#      35 if not norm_doi:
# ---> 36     raise ValueError(f"Invalid DOI: {doi}")
#      38 s = session or make_session(allowed_methods=("GET",))
#      39 return get_datacite_record_by_norm_doi(norm_doi, session=s)
#
# ValueError: Invalid DOI: https://fairhub.io/datasets/2

# %%
dois = ["10.13026/kpb9-mt58", "10.60775/fairhub.2"]

out_dir = Path("output/datacite/harvest_doi_list_test")
out_dir.mkdir(parents=True, exist_ok=True)

harvest_datacite_doi_list_to_ndjson(
    doi_list=dois,
    output_folder=str(out_dir),
    batch_size=1,
)

print(f"Done. Check: {out_dir.resolve()}")
# Out:
# Fetching 10.13026/kpb9-mt58 ...
#   Writing 1 metadata records → output\datacite\harvest_doi_list_test\datacite-batch-0000.ndjson
# Fetching 10.60775/fairhub.2 ...
#   Writing 1 metadata records → output\datacite\harvest_doi_list_test\datacite-batch-0001.ndjson
# Done. Check: C:\Users\Admin\Documents\GitHub\sindex-pipeline\notebooks\output\datacite\harvest_doi_list_test

# %% [markdown]
# ## Write records to ndjson for date range

# %%
start_date_str = "2014-12-28"
end_date_str = "2015-01-10"

out_dir = Path("output/datacite/harvest_date_range_test")
out_dir.mkdir(parents=True, exist_ok=True)

n = harvest_datacite_datasets_for_date_range_to_ndjson(
    start_date_str=start_date_str,
    end_date_str=end_date_str,
    window_days=7,  
    page_size=1000,
    save_folder=str(out_dir),
    skip_empty_files=True,
    polite_sleep_seconds=0.5,
)

print(f"Done. Wrote {n:,} records across window files in {out_dir.resolve()}")
# Out:
# Fetching records 2015-01-04 → 2015-01-10 (window_days=7, page_size=1000, detail=True)
#   Saved 2468 records → output\datacite\harvest_date_range_test\datacite-2015-01-04-2015-01-10.ndjson
# Fetching records 2015-01-01 → 2015-01-03 (window_days=7, page_size=1000, detail=True)
#   Saved 787 records → output\datacite\harvest_date_range_test\datacite-2015-01-01-2015-01-03.ndjson
# Fetching records 2014-12-28 → 2014-12-31 (window_days=7, page_size=1000, detail=True)
#   Saved 821 records → output\datacite\harvest_date_range_test\datacite-2014-12-28-2014-12-31.ndjson
# Finished harvest. Total records saved: 4076
# Done. Wrote 4,076 records across window files in C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-test\output\datacite\harvest_date_range_test

# %% [markdown]
# ## Write batch slim records

# %%
# Folder containing raw DataCite NDJSON or NDJSON.GZ files
src_folder = Path("output/datacite/harvest_date_range_test")

# Folder where slimmed outputs will be written
dst_folder = Path("output/datacite/batch_slim_test")

# Folder check
if not src_folder.exists():
    raise FileNotFoundError(f"Source folder does not exist: {src_folder.resolve()}")

dst_folder.mkdir(parents=True, exist_ok=True)

print("Running DataCite batch slimming test")
print(f"  Input folder : {src_folder.resolve()}")
print(f"  Output folder: {dst_folder.resolve()}")
print("---")

# Run the batch slim function
summary = batch_slim_datacite_record_to_ndjson(
    src_folder=str(src_folder),
    dst_folder=str(dst_folder),
    overwrite=True,
    accept_gz=True,
    one_line_progress=True
)

# Summary
print("\nSummary:")
display(summary)
# Out:
# Running DataCite batch slimming test
#   Input folder : C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-test\output\datacite\harvest_date_range_test
#   Output folder: C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-test\output\datacite\batch_slim_test
# ---
# [3/3] files completed
# Done. files=3 kept=4,076 bad=0 time=0.6s rate≈6,802/s → C:\Users\BPatel\Documents\GitHub\sindex-pipeline\notebooks-test\output\datacite\batch_slim_test
#
# Summary:
# {'files_seen': 3,
#  'records_read': 4076,
#  'records_kept': 4076,
#  'records_bad_json': 0,
#  'output_dir': 'C:\\Users\\BPatel\\Documents\\GitHub\\sindex-pipeline\\notebooks-test\\output\\datacite\\batch_slim_test',
#  'elapsed_sec': 0.6,
#  'rate_rec_per_sec': 6802}
