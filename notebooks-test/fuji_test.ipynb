# %% [markdown]
# # F-UJI FAIR score test

# %% [markdown]
# Needs a running local f-uji server:
# Installation with conda:
# 1) Clone the F-UJI repo: https://github.com/pangaea-data-publisher/fuji
# 2) Create a python env with the correct Python version e.g.: ```conda create -n fuji python=3.11 -y``` and activate the environment
# 3) Go to the F-UJI directory in the Anaconda command prompt and install required packages: ```python -m pip install .```
# 4) Add credentials in ```fuji_server/config/users.py```, e.g., ``` fuji_users = {"bhavesh": "mystrongpassword"} ```
# 5) Start F-UJI server: ```python -m fuji_server -c fuji_server/config/server.ini```

# %% [markdown]
# ## Import

# %%
from sindex.sources.fuji.jobs import fair_evaluation_report

# %% [markdown]
# ## Tests

# %% [markdown]
# ### Working DOI URL

# %%
doi_or_url = "https://doi.org/10.60775/fairhub.2"
fair_evaluation_report(
    doi_or_url
    )
# Out:
# {'fair_score': 96.15,
#  'evaluation_date': '2026-01-20T19:23:01+00:00',
#  'fuji_metric_version': '0.8',
#  'fuji_software_version': '3.5.1'}

# %% [markdown]
# ### Broken DOI URL

# %%
doi_or_url = "https://doi.org/10.60775/fairhub.5"
fair_evaluation_report(
    doi_or_url
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 doi_or_url = "https://doi.org/10.60775/fairhub.5"
# ----> 2 fair_evaluation_report(
#       3     doi_or_url
#       4     )
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\jobs.py:23, in fair_evaluation_report(doi_or_url, base_url, username, password, session)
#      10 def fair_evaluation_report(
#      11     doi_or_url: str,
#      12     *,
#    (...)     16     session: requests.Session | None = None,
#      17 ) -> dict:
#      18     """
#      19     Wrapper:
#      20       - discovery.fair_evaluate_doi_url() -> raw F-UJI JSON
#      21       - normalize.fuji_report_from_response() -> compact FAIR report
#      22     """
# ---> 23     raw = fair_evaluate_doi_url(
#      24         doi_or_url,
#      25         base_url=base_url,
#      26         username=username,
#      27         password=password,
#      28         session=session,
#      29     )
#      30     return fuji_report_from_response(raw)
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\discovery.py:66, in fair_evaluate_doi_url(doi_or_url, base_url, username, password, session)
#      40 """
#      41 Run a FAIR evaluation for a given DOI URL or URL using a local F-UJI instance.
#      42
#    (...)     62     raw F-UJI response
#      63 """
#      64 s = session or make_session(allowed_methods=("POST",))
# ---> 66 object_identifier = resolve_fuji_object_identifier(doi_or_url, session=s)
#      68 return fuji_evaluate(
#      69     object_identifier,
#      70     session=s,
#    (...)     73     password=password,
#      74 )
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\discovery.py:29, in resolve_fuji_object_identifier(doi_or_url, session)
#      26 if is_working_url(doi_or_url, session=session):
#      27     return doi_or_url
# ---> 29 raise ValueError(f"Identifier '{doi_or_url}' is not a working DOI or URL.")
#
# ValueError: Identifier 'https://doi.org/10.60775/fairhub.5' is not a working DOI or URL.

# %% [markdown]
# ### Working Canonical DOI

# %%
doi_or_url = "10.60775/fairhub.2"
fair_evaluation_report(
    doi_or_url
    )
# Out:
# {'fair_score': 96.15,
#  'evaluation_date': '2026-01-13T19:18:00+00:00',
#  'fuji_metric_version': '0.8',
#  'fuji_software_version': '3.5.1'}

# %% [markdown]
# ### Broken Canonical DOI

# %%
doi_or_url = "10.60675/fairhub.2"
fair_evaluation_report(
    doi_or_url
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 doi_or_url = "10.60675/fairhub.2"
# ----> 2 fair_evaluation_report(
#       3     doi_or_url
#       4     )
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\jobs.py:23, in fair_evaluation_report(doi_or_url, base_url, username, password, session)
#      10 def fair_evaluation_report(
#      11     doi_or_url: str,
#      12     *,
#    (...)     16     session: requests.Session | None = None,
#      17 ) -> dict:
#      18     """
#      19     Wrapper:
#      20       - discovery.fair_evaluate_doi_url() -> raw F-UJI JSON
#      21       - normalize.fuji_report_from_response() -> compact FAIR report
#      22     """
# ---> 23     raw = fair_evaluate_doi_url(
#      24         doi_or_url,
#      25         base_url=base_url,
#      26         username=username,
#      27         password=password,
#      28         session=session,
#      29     )
#      30     return fuji_report_from_response(raw)
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\discovery.py:66, in fair_evaluate_doi_url(doi_or_url, base_url, username, password, session)
#      40 """
#      41 Run a FAIR evaluation for a given DOI URL or URL using a local F-UJI instance.
#      42
#    (...)     62     raw F-UJI response
#      63 """
#      64 s = session or make_session(allowed_methods=("POST",))
# ---> 66 object_identifier = resolve_fuji_object_identifier(doi_or_url, session=s)
#      68 return fuji_evaluate(
#      69     object_identifier,
#      70     session=s,
#    (...)     73     password=password,
#      74 )
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\discovery.py:29, in resolve_fuji_object_identifier(doi_or_url, session)
#      26 if is_working_url(doi_or_url, session=session):
#      27     return doi_or_url
# ---> 29 raise ValueError(f"Identifier '{doi_or_url}' is not a working DOI or URL.")
#
# ValueError: Identifier '10.60675/fairhub.2' is not a working DOI or URL.

# %% [markdown]
# ### Working Dataset URL

# %%
doi_or_url = "https://fairhub.io/datasets/2"
fair_evaluation_report(
    doi_or_url
    )
# Out:
# {'fair_score': 92.31,
#  'evaluation_date': '2026-01-13T19:18:14+00:00',
#  'fuji_metric_version': '0.8',
#  'fuji_software_version': '3.5.1'}

# %% [markdown]
# ### Broken Dataset URL

# %%
doi_or_url = "https://fairhub.io/datasets/5"
fair_evaluation_report(
    doi_or_url
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 doi_or_url = "https://fairhub.io/datasets/5"
# ----> 2 fair_evaluation_report(
#       3     doi_or_url
#       4     )
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\jobs.py:23, in fair_evaluation_report(doi_or_url, base_url, username, password, session)
#      10 def fair_evaluation_report(
#      11     doi_or_url: str,
#      12     *,
#    (...)     16     session: requests.Session | None = None,
#      17 ) -> dict:
#      18     """
#      19     Wrapper:
#      20       - discovery.fair_evaluate_doi_url() -> raw F-UJI JSON
#      21       - normalize.fuji_report_from_response() -> compact FAIR report
#      22     """
# ---> 23     raw = fair_evaluate_doi_url(
#      24         doi_or_url,
#      25         base_url=base_url,
#      26         username=username,
#      27         password=password,
#      28         session=session,
#      29     )
#      30     return fuji_report_from_response(raw)
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\discovery.py:66, in fair_evaluate_doi_url(doi_or_url, base_url, username, password, session)
#      40 """
#      41 Run a FAIR evaluation for a given DOI URL or URL using a local F-UJI instance.
#      42
#    (...)     62     raw F-UJI response
#      63 """
#      64 s = session or make_session(allowed_methods=("POST",))
# ---> 66 object_identifier = resolve_fuji_object_identifier(doi_or_url, session=s)
#      68 return fuji_evaluate(
#      69     object_identifier,
#      70     session=s,
#    (...)     73     password=password,
#      74 )
#
# File ~\Documents\GitHub\sindex-pipeline\src\sindex\sources\fuji\discovery.py:29, in resolve_fuji_object_identifier(doi_or_url, session)
#      26 if is_working_url(doi_or_url, session=session):
#      27     return doi_or_url
# ---> 29 raise ValueError(f"Identifier '{doi_or_url}' is not a working DOI or URL.")
#
# ValueError: Identifier 'https://fairhub.io/datasets/5' is not a working DOI or URL.
