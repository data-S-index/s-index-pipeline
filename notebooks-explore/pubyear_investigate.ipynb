# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pubyear import analyze_json_files

# %%
folder_path = r"D:\pipeline-data\records\slim-records"
#folder_path = r"D:\pipeline-data\records\slim-records\emdb-slim-records"
analyze_json_files(folder_path, "pubyear")
# Out:
# Scanning for files...
# Found 492 files. Starting processing...
# Progress: 492/492 files processed (100.0%)
# Processing complete in 25.92 seconds.
# Saving CSV reports...
# Saved: pubyear\pubyear_count.csv
# Saved: pubyear\publication_year_count.csv
# Saved: pubyear\published_per_year_count.csv
# Saved: pubyear\doi_created_date_per_year_count.csv
#
# --- Summary ---
# Total Records Scanned: 49,061,167
# Records with 'pubyear':          49,061,167
# Records with 'publication_year': 49,009,284
# Records with 'published':        0
# Records with 'doi_created_date': 49,009,522
