# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pubyear import analyze_json_files

# %%
folder_path = r"D:\pipeline-data\records\slim-records"
#folder_path = r"D:\pipeline-data\records\slim-records\emdb-slim-records"
analyze_json_files(folder_path, "pubyear")
# Out:
# Scanning for files...
# Found 772 files. Starting processing...
# Progress: 772/772 files processed (100.0%)
# Merging 'none' records into none.ndjson...
# Processing complete in 28.03 seconds.
# Saving statistics...
#
# Summary:
#   Total Records:   49,061,167
#   Both Dates:      49,009,288
#   Just Created:    234
#   Just Published:  51,645
#   No Dates (None): 0 (Saved to none.ndjson)
